# %% [markdown]
# <a href="https://colab.research.google.com/github/Reuel-Christian-Pornobe/VDA-CPE031-CPE21S4/blob/main/Pornobe_Midterm_Exam_VDA(with_nans).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## With NaNs format (with null or Non number in the data set)

# %% [markdown]
# ### **Importing CSV File**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-97e73b0b-10cb-4f48-b3e8-72e8c7562ce9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-97e73b0b-10cb-4f48-b3e8-72e8c7562ce9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### **Creating a DataFrame**

# %%
import pandas as pd
import csv

df = pd.read_csv('heart_2022_with_nans.csv')


print(df)
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 0              Alabama  Female     Very good                 0.0
# 1              Alabama  Female     Excellent                 0.0
# 2              Alabama  Female     Very good                 2.0
# 3              Alabama  Female     Excellent                 0.0
# 4              Alabama  Female          Fair                 2.0
# ...                ...     ...           ...                 ...
# 445127  Virgin Islands  Female          Good                 0.0
# 445128  Virgin Islands  Female     Excellent                 2.0
# 445129  Virgin Islands  Female          Poor                30.0
# 445130  Virgin Islands    Male     Very good                 0.0
# 445131  Virgin Islands    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 0                    0.0  Within past year (anytime less than 12 months ...
# ...

# %% [markdown]
# ### **1. Which State has the highest amount of people with Heart Disease?**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


state_counts = df['State'].value_counts()

plt.figure(figsize=(12, 8))
plt.bar(state_counts.index, state_counts.values)

plt.title('People with Heart Disease by State')
plt.xlabel('States')
plt.ylabel('Number of People with Heart Disease')

plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# The state with the highest amount of people with Heart Disease is Washington, while the state with the lowest amount of people with Heart disease is Virgin Islands. This information tells us which states need a priority to increase heart care, which is the Washington State.

# %% [markdown]
# ### **2. Is there a relationship between Body Mass Index and Heart Attack**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


# category creation for bmi
bmi_bins = [0, 25, 30, 35, 40, float('inf')]  # Example ranges, adjust as needed
bmi_labels = ['Underweight', 'Healthy', 'Overweight', 'Obese', 'Severely Obese']

# column for bmi category
df['BMI_Category'] = pd.cut(df['BMI'], bins=bmi_bins, labels=bmi_labels)

# grouping bmi category and heart attack occurences
bmi_heart_attack_counts = df.groupby(['BMI_Category', 'HadHeartAttack'])['HadHeartAttack'].count().unstack()


bmi_heart_attack_counts.plot(kind='bar', figsize=(10, 6))

plt.title('Relationship between BMI and Heart Attack Cases')
plt.xlabel('BMI Category')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Heart Attack')

plt.show()
# Out:
# <ipython-input-7-6c35f8a31b07>:14: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bmi_heart_attack_counts = df.groupby(['BMI_Category', 'HadHeartAttack'])['HadHeartAttack'].count().unstack()

# %% [markdown]
# The amount of people with Heart disease with the category of Healthy Body Mass Index is surpisingly the majority. Furthemore, it tells us that people with healthy BMI is the majority for heart attack cases. The graph shows that BMI does not have a significant relationship with Heart attack cases.
